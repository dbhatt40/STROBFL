# %% [markdown]
# <a href="https://colab.research.google.com/github/dbhatt40/STROBFL/blob/main/STROBFL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dbhatt40/STROBFL.git
# Out:
# Cloning into 'STROBFL'...
# remote: Enumerating objects: 250, done.
# remote: Counting objects: 100% (250/250), done.
# remote: Compressing objects: 100% (205/205), done.
# remote: Total 250 (delta 114), reused 119 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (250/250), 27.66 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
# !bash ./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-10-22 15:14:03--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   194MB/s    in 0.3s
#
# 2025-10-22 15:14:03 (194 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !conda upgrade -n base conda
# Out:
# done
# |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::yaml==0.1.7=had09818_2
#   - defaults/linux-64::pysocks==1.6.8=py36_0
#   - defaults/linux-64::ruamel_yaml==0.15.37=py36h14c3975_2
#   - defaults/linux-64::asn1crypto==0.24.0=py36_0
#   - defaults/linux-64::chardet==3.0.4=py36h0f667ec_1
#   - defaults/linux-64::six==1.11.0=py36h372c433_1
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.5             |     pyhd3eb1b0_0          48 KB
#     boltons-25.0.0             |  py313h06a4308_0         510 KB
#     brotlicffi-1.0.9.2         |  py313h6a678d5_1         365 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     c-ares-1.34.5              |       hef5626c_0         216 KB
#     certifi-2025.10.5          |  py313h06a4308_0         158 KB
#     cffi-2.0.0                 |  py313h4eded50_0         290 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda-25.9.1               |  py313h06a4308_0         1.2 MB
#     conda-libmamba-solver-25.4.0|     pyhd3eb1b0_0          40 KB
#     conda-package-handling-2.4.0|  py313h06a4308_0         282 KB
#     conda-package-streaming-0.12.0|  py313h06a4308_0          39 KB
#     cpp-expected-1.1.0         |       hdb19cb5_0         130 KB
#     distro-1.9.0               |  py313h06a4308_0          37 KB
#     expat-2.7.1                |       h6a678d5_0         182 KB
#     fmt-11.2.0                 |       hca5f364_0         202 KB
#     frozendict-2.4.2           |  py313h06a4308_0          36 KB
#     icu-73.1                   |       h6a678d5_0        25.9 MB
#     idna-3.7                   |  py313h06a4308_0         104 KB
#     jsonpatch-1.33             |  py313h06a4308_1          36 KB
#     jsonpointer-3.0.0          |  py313h06a4308_0          21 KB
#     ld_impl_linux-64-2.44      |       h153f514_2         672 KB
#     libarchive-3.8.1           |       h13d4d48_0         954 KB
#     libcurl-8.15.0             |       hc1efc7f_0         498 KB
#     libev-4.33                 |       h7f8727e_1         111 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libmamba-2.3.2             |       h4368100_0         2.0 MB
#     libmambapy-2.3.2           |  py313hea2f153_0         648 KB
#     libmpdec-4.0.0             |       h5eee18b_0          86 KB
#     libnghttp2-1.57.0          |       h2d74bed_0         674 KB
#     libsolv-0.7.30             |       h6f1ccf3_2         455 KB
#     libssh2-1.11.1             |       h251f7ec_0         308 KB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     libxml2-2.13.8             |       hfdd30dd_0         739 KB
#     libzlib-1.3.1              |       hb25bd0a_0          59 KB
#     lz4-c-1.9.4                |       h6a678d5_1         156 KB
#     menuinst-2.3.1             |  py313h06a4308_0         263 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     nlohmann_json-3.11.2       |       h6a678d5_0         124 KB
#     openssl-3.0.18             |       hd6dcaed_0         4.5 MB
#     packaging-25.0             |  py313h06a4308_1         190 KB
#     pcre2-10.46                |       hf426167_0         1.2 MB
#     pip-25.2                   |     pyhc872135_1         1.1 MB
#     platformdirs-4.3.7         |  py313h06a4308_0          41 KB
#     pluggy-1.5.0               |  py313h06a4308_0          46 KB
#     pthread-stubs-0.3          |       h0ce48e5_1           5 KB
#     pybind11-abi-5             |       hd3eb1b0_0          14 KB
#     pycosat-0.6.6              |  py313h5eee18b_2          91 KB
#     pycparser-2.23             |  py313h06a4308_0         275 KB
#     python-3.13.9              |h7e8bc2b_100_cp313        34.9 MB
#     python_abi-3.13            |          1_cp313           6 KB
#     readline-8.3               |       hc2a1206_0         471 KB
#     reproc-14.2.4              |       h6a678d5_2          29 KB
#     reproc-cpp-14.2.4          |       h6a678d5_2          21 KB
#     requests-2.32.5            |  py313h06a4308_0         176 KB
#     ruamel.yaml-0.18.10        |  py313h5eee18b_0         273 KB
#     ruamel.yaml.clib-0.2.12    |  py313h5eee18b_0         155 KB
#     setuptools-80.9.0          |  py313h06a4308_0         1.9 MB
#     simdjson-3.10.1            |       hdb19cb5_0         258 KB
#     sqlite-3.50.2              |       hb25bd0a_1         1.1 MB
#     tk-8.6.15                  |       h54e0aa7_0         3.4 MB
#     tqdm-4.67.1                |  py313h7040dfc_0         162 KB
#     truststore-0.10.1          |  py313h06a4308_0          50 KB
#     urllib3-2.5.0              |  py313h06a4308_0         363 KB
#     wheel-0.45.1               |  py313h06a4308_0         144 KB
#     xorg-libx11-1.8.12         |       h9b100fa_1         895 KB
#     xorg-libxau-1.0.12         |       h9b100fa_0          13 KB
#     xorg-libxdmcp-1.1.5        |       h9b100fa_0          19 KB
#     xorg-xorgproto-2024.1      |       h5eee18b_1         580 KB
#     xz-5.6.4                   |       h5eee18b_1         567 KB
#     yaml-cpp-0.8.0             |       h6a678d5_1         607 KB
#     zlib-1.3.1                 |       hb25bd0a_0          96 KB
#     zstandard-0.24.0           |  py313h3d778a8_0         413 KB
#     zstd-1.5.7                 |       h11fc155_0         608 KB
#     ------------------------------------------------------------
#                                            Total:        93.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   archspec           pkgs/main/noarch::archspec-0.2.5-pyhd3eb1b0_0
#   brotlicffi         pkgs/main/linux-64::brotlicffi-1.0.9.2-py313h6a678d5_1
#   c-ares             pkgs/main/linux-64::c-ares-1.34.5-hef5626c_0
#   conda-libmamba-so~ pkgs/main/noarch::conda-libmamba-solver-25.4.0-pyhd3eb1b0_0
#   cpp-expected       pkgs/main/linux-64::cpp-expected-1.1.0-hdb19cb5_0
#   distro             pkgs/main/linux-64::distro-1.9.0-py313h06a4308_0
#   expat              pkgs/main/linux-64::expat-2.7.1-h6a678d5_0
#   fmt                pkgs/main/linux-64::fmt-11.2.0-hca5f364_0
#   frozendict         pkgs/main/linux-64::frozendict-2.4.2-py313h06a4308_0
#   icu                pkgs/main/linux-64::icu-73.1-h6a678d5_0
#   libarchive         pkgs/main/linux-64::libarchive-3.8.1-h13d4d48_0
#   libcurl            pkgs/main/linux-64::libcurl-8.15.0-hc1efc7f_0
#   libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libmamba           pkgs/main/linux-64::libmamba-2.3.2-h4368100_0
#   libmambapy         pkgs/main/linux-64::libmambapy-2.3.2-py313hea2f153_0
#   libmpdec           pkgs/main/linux-64::libmpdec-4.0.0-h5eee18b_0
#   libnghttp2         pkgs/main/linux-64::libnghttp2-1.57.0-h2d74bed_0
#   libsolv            pkgs/main/linux-64::libsolv-0.7.30-h6f1ccf3_2
#   libssh2            pkgs/main/linux-64::libssh2-1.11.1-h251f7ec_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libxml2            pkgs/main/linux-64::libxml2-2.13.8-hfdd30dd_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h6a678d5_1
#   menuinst           pkgs/main/linux-64::menuinst-2.3.1-py313h06a4308_0
#   nlohmann_json      pkgs/main/linux-64::nlohmann_json-3.11.2-h6a678d5_0
#   pcre2              pkgs/main/linux-64::pcre2-10.46-hf426167_0
#   platformdirs       pkgs/main/linux-64::platformdirs-4.3.7-py313h06a4308_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   pybind11-abi       pkgs/main/noarch::pybind11-abi-5-hd3eb1b0_0
#   python_abi         pkgs/main/linux-64::python_abi-3.13-1_cp313
#   reproc             pkgs/main/linux-64::reproc-14.2.4-h6a678d5_2
#   reproc-cpp         pkgs/main/linux-64::reproc-cpp-14.2.4-h6a678d5_2
#   simdjson           pkgs/main/linux-64::simdjson-3.10.1-hdb19cb5_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   yaml-cpp           pkgs/main/linux-64::yaml-cpp-0.8.0-h6a678d5_1
#   zstd               pkgs/main/linux-64::zstd-1.5.7-h11fc155_0
#
# The following packages will be UPDATED:
#
#   bzip2                                    1.0.8-h7b6447c_0 --> 1.0.8-h5eee18b_6
#   cffi                               1.15.0-py310hd667e15_1 --> 2.0.0-py313h4eded50_0
#   conda                              23.9.0-py310h06a4308_0 --> 25.9.1-py313h06a4308_0
#   ld_impl_linux-64                          2.40-h12ee557_0 --> 2.44-h153f514_2
#   libffi                                     3.3-he6710b0_2 --> 3.4.4-h6a678d5_1
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1
#   libuuid                                  1.0.3-h7f8727e_2 --> 1.41.5-h5eee18b_0
#   ncurses                                    6.3-h7f8727e_2 --> 6.5-h7934f7d_0
#   openssl                                 1.1.1w-h7f8727e_0 --> 3.0.18-hd6dcaed_0
#   pycosat                             0.6.3-py310h7f8727e_0 --> 0.6.6-py313h5eee18b_2
#   python                                  3.10.4-h12debd9_0 --> 3.13.9-h7e8bc2b_100_cp313
#   readline                                 8.1.2-h7f8727e_1 --> 8.3-hc2a1206_0
#   ruamel.yaml                       0.16.10-py310h7f8727e_1 --> 0.18.10-py313h5eee18b_0
#   ruamel.yaml.clib                    0.2.6-py310h7f8727e_0 --> 0.2.12-py313h5eee18b_0
#   sqlite                                  3.38.5-hc218d9a_0 --> 3.50.2-hb25bd0a_1
#   tk                                      8.6.12-h1ccaba5_0 --> 8.6.15-h54e0aa7_0
#   urllib3                             2.1.0-py310h06a4308_0 --> 2.5.0-py313h06a4308_0
#   xz                                       5.2.5-h7f8727e_1 --> 5.6.4-h5eee18b_1
#   zlib                                    1.2.12-h7f8727e_2 --> 1.3.1-hb25bd0a_0
#   zstandard                          0.15.2-py310h7f8727e_0 --> 0.24.0-py313h3d778a8_0
#
# The following packages will be DOWNGRADED:
#
#   boltons                            25.0.0-py310h06a4308_0 --> 25.0.0-py313h06a4308_0
#   certifi                         2025.10.5-py310h06a4308_0 --> 2025.10.5-py313h06a4308_0
#   conda-package-han~                  2.4.0-py310h06a4308_0 --> 2.4.0-py313h06a4308_0
#   conda-package-str~                 0.12.0-py310h06a4308_0 --> 0.12.0-py313h06a4308_0
#   idna                                  3.7-py310h06a4308_0 --> 3.7-py313h06a4308_0
#   jsonpatch                            1.33-py310h06a4308_1 --> 1.33-py313h06a4308_1
#   jsonpointer                         3.0.0-py310h06a4308_0 --> 3.0.0-py313h06a4308_0
#   packaging                            25.0-py310h06a4308_1 --> 25.0-py313h06a4308_1
#   pluggy                              1.5.0-py310h06a4308_0 --> 1.5.0-py313h06a4308_0
#   pycparser                            2.23-py310h06a4308_0 --> 2.23-py313h06a4308_0
#   requests                           2.32.5-py310h06a4308_0 --> 2.32.5-py313h06a4308_0
#   setuptools                         80.9.0-py310h06a4308_0 --> 80.9.0-py313h06a4308_0
#   tqdm                               4.67.1-py310h2f386ee_0 --> 4.67.1-py313h7040dfc_0
#   truststore                         0.10.1-py310h06a4308_0 --> 0.10.1-py313h06a4308_0
#   wheel                              0.45.1-py310h06a4308_0 --> 0.45.1-py313h06a4308_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages:
# libzlib-1.3.1        | 59 KB     | :   0% 0/1 [00:00<?, ?it/s]
# zlib-1.3.1           | 96 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# platformdirs-4.3.7   | 41 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# reproc-14.2.4        | 29 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libxcb-1.17.0        | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# charset-normalizer-3 | 44 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ruamel.yaml-0.18.10  | 273 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# frozendict-2.4.2     | 36 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# conda-package-handli | 282 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 130 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# boltons-25.0.0       | 510 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# brotlicffi-1.0.9.2   | 365 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.5      | 176 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.13      | 6 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 40 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 91 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# archspec-0.2.5       | 48 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# reproc-14.2.4        | 29 KB     | : 100% 1.0/1 [00:00<00:00,  9.81it/s]
#
#
# reproc-14.2.4        | 29 KB     | : 100% 1.0/1 [00:00<00:00,  9.81it/s]
# zlib-1.3.1           | 96 KB     | :  17% 0.16692817116658176/1 [00:00<00:00,  1.57it/s]
#
#
#
# libzlib-1.3.1        | 59 KB     | : 100% 1.0/1 [00:00<00:00,  7.27it/s]
#
#
#
#
# charset-normalizer-3 | 44 KB     | :  36% 0.3598111342923026/1 [00:00<00:00,  2.77it/s]
# zlib-1.3.1           | 96 KB     | : 100% 1.0/1 [00:00<00:00,  1.57it/s]
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   3% 0.03400397653924861/1 [00:00<00:04,  4.31s/it]
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   3% 0.02757436782092818/1 [00:00<00:06,  6.71s/it]
#
#
#
#
#
#
#
#
#
# conda-package-handli | 282 KB    | :   6% 0.05671421697757255/1 [00:00<00:03,  3.79s/it]
#
#
#
#
# charset-normalizer-3 | 44 KB     | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
#
#
#
#
#
#
# readline-8.3         | 471 KB    | : 100% 1.0/1 [00:00<00:00,  4.31s/it]
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 130 KB    | :  12% 0.12347856233089903/1 [00:00<00:01,  2.09s/it]
#
#
#
#
#
#
#
#
#
#
#
# boltons-25.0.0       | 510 KB    | :   3% 0.0313612593505708/1 [00:00<00:08,  8.57s/it]
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:00<00:00,  3.95it/s]
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:00<00:00,  3.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# brotlicffi-1.0.9.2   | 365 KB    | :   4% 0.04380385583013173/1 [00:00<00:06,  6.92s/it]
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 130 KB    | : 100% 1.0/1 [00:00<00:00,  2.09s/it]
#
# platformdirs-4.3.7   | 41 KB     | :  39% 0.3866978215204513/1 [00:00<00:00,  1.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.5      | 176 KB    | :   9% 0.09072082747317246/1 [00:00<00:03,  3.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.13      | 6 KB      | : 100% 1.0/1 [00:00<00:00,  2.79it/s]
#
#
#
#
#
#
#
#
#
# conda-package-handli | 282 KB    | : 100% 1.0/1 [00:00<00:00,  3.22it/s]
#
#
#
#
#
#
#
#
#
# conda-package-handli | 282 KB    | : 100% 1.0/1 [00:00<00:00,  3.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 40 KB     | :  40% 0.4033679649416515/1 [00:00<00:00,  1.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# archspec-0.2.5       | 48 KB     | :  33% 0.3325957654128012/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# brotlicffi-1.0.9.2   | 365 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# brotlicffi-1.0.9.2   | 365 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
#
#
#
#
#
# ruamel.yaml-0.18.10  | 273 KB    | :   6% 0.058517211574864454/1 [00:00<00:07,  7.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# platformdirs-4.3.7   | 41 KB     | : 100% 1.0/1 [00:00<00:00,  2.13it/s]
#
# platformdirs-4.3.7   | 41 KB     | : 100% 1.0/1 [00:00<00:00,  2.13it/s]
#
#
#
#
#
#
#
#
#
#
#
# boltons-25.0.0       | 510 KB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
#
#
#
#
#
#
#
#
#
#
#
# boltons-25.0.0       | 510 KB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.13      | 6 KB      | : 100% 1.0/1 [00:00<00:00,  2.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 40 KB     | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-libmamba-solve | 40 KB     | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.5      | 176 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.5      | 176 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# archspec-0.2.5       | 48 KB     | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# archspec-0.2.5       | 48 KB     | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
#
#
#
#
#
# ruamel.yaml-0.18.10  | 273 KB    | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
#
#
#
#
#
# ruamel.yaml-0.18.10  | 273 KB    | : 100% 1.0/1 [00:00<00:00,  1.26it/s]
#
#
#
#
#
#
#
# frozendict-2.4.2     | 36 KB     | :  44% 0.43904922689390896/1 [00:00<00:01,  2.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# frozendict-2.4.2     | 36 KB     | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
# frozendict-2.4.2     | 36 KB     | : 100% 1.0/1 [00:01<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 91 KB     | :  18% 0.17606791682338402/1 [00:02<00:11, 14.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 91 KB     | : 100% 1.0/1 [00:05<00:00,  5.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.6        | 91 KB     | : 100% 1.0/1 [00:05<00:00,  5.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# # New Section

# %%
# !conda env create -f STROBFL/environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
#
# CondaValueError: prefix already exists: /usr/local/envs/tf

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.13/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.

# %%
# !conda activate tf
# Out:
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# tf                       /usr/local/envs/tf

# %%
# !cp -r /content/STROBFL/ /content/drive/MyDrive/STROBFL

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 131.3 MB/s  0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 174.1 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pandas]
# Successfully installed numpy-2.2.6 pandas-2.3.3 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
import os
import shutil
cdir = os.getcwd()
cdir = cdir+"/STROBFL"
shutil.rmtree(cdir)
