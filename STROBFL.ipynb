# %% [markdown]
# <a href="https://colab.research.google.com/github/dbhatt40/STROBFL/blob/main/STROBFL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dbhatt40/STROBFL.git
# Out:
# Cloning into 'STROBFL'...
# remote: Enumerating objects: 253, done.
# remote: Counting objects: 100% (253/253), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 253 (delta 115), reused 118 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (253/253), 27.66 MiB | 20.13 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
# !bash ./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-10-22 20:39:27--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M  24.0MB/s    in 2.3s
#
# 2025-10-22 20:39:30 (24.0 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !conda upgrade -n base conda
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     xz-5.2.5                   |       h7f8727e_1         389 KB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     cffi-1.15.0                |  py310hd667e15_1         407 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     packaging-25.0             |  py310h06a4308_1         161 KB
#     boltons-25.0.0             |  py310h06a4308_0         422 KB
#     truststore-0.10.1          |  py310h06a4308_0          41 KB
#     pyopenssl-23.2.0           |  py310h06a4308_0          93 KB
#     pip-25.2                   |     pyhc872135_1         1.4 MB
#     conda-package-handling-2.4.0|  py310h06a4308_0         275 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         706 KB
#     conda-package-streaming-0.12.0|  py310h06a4308_0          33 KB
#     conda-23.9.0               |  py310h06a4308_0         994 KB
#     requests-2.32.5            |  py310h06a4308_0         143 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.8 MB
#     urllib3-2.1.0              |  py310h06a4308_0         143 KB
#     tqdm-4.67.1                |  py310h2f386ee_0         125 KB
#     ca-certificates-2025.9.9   |       h06a4308_0         133 KB
#     tzdata-2025b               |       h04d1e81_0         123 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          42 KB
#     certifi-2025.10.5          |  py310h06a4308_0         159 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     python-3.10.4              |       h12debd9_0        24.2 MB
#     zstandard-0.15.2           |  py310h7f8727e_0         2.5 MB
#     ruamel.yaml-0.16.10        |  py310h7f8727e_1         170 KB
#     ruamel.yaml.clib-0.2.6     |  py310h7f8727e_0         547 KB
#     pluggy-1.5.0               |  py310h06a4308_0          37 KB
#     wheel-0.45.1               |  py310h06a4308_0         108 KB
#     pycosat-0.6.3              |  py310h7f8727e_0         206 KB
#     sqlite-3.38.5              |       hc218d9a_0         1.5 MB
#     setuptools-80.9.0          |  py310h06a4308_0         1.8 MB
#     tk-8.6.12                  |       h1ccaba5_0         3.3 MB
#     zlib-1.2.12                |       h7f8727e_2         130 KB
#     cryptography-41.0.3        |  py310h130f0dd_0         2.1 MB
#     libuuid-1.0.3              |       h7f8727e_2          18 KB
#     pycparser-2.23             |  py310h06a4308_0         239 KB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     jsonpointer-3.0.0          |  py310h06a4308_0          19 KB
#     jsonpatch-1.33             |  py310h06a4308_1          31 KB
#     idna-3.7                   |  py310h06a4308_0         136 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     ------------------------------------------------------------
#                                            Total:        60.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:           0.1-main
#     boltons:                 25.0.0-py310h06a4308_0
#     bzip2:                   1.0.8-h7b6447c_0
#     charset-normalizer:      3.3.2-pyhd3eb1b0_0
#     conda-package-handling:  2.4.0-py310h06a4308_0
#     conda-package-streaming: 0.12.0-py310h06a4308_0
#     jsonpatch:               1.33-py310h06a4308_1
#     jsonpointer:             3.0.0-py310h06a4308_0
#     ld_impl_linux-64:        2.40-h12ee557_0
#     libuuid:                 1.0.3-h7f8727e_2
#     packaging:               25.0-py310h06a4308_1
#     pluggy:                  1.5.0-py310h06a4308_0
#     ruamel.yaml:             0.16.10-py310h7f8727e_1
#     ruamel.yaml.clib:        0.2.6-py310h7f8727e_0
#     tqdm:                    4.67.1-py310h2f386ee_0
#     truststore:              0.10.1-py310h06a4308_0
#     tzdata:                  2025b-h04d1e81_0
#     zstandard:               0.15.2-py310h7f8727e_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:         2018.03.07-0            --> 2025.9.9-h06a4308_0
#     certifi:                 2018.4.16-py36_0        --> 2025.10.5-py310h06a4308_0
#     cffi:                    1.11.5-py36h9745a5d_0   --> 1.15.0-py310hd667e15_1
#     conda:                   4.5.4-py36_0            --> 23.9.0-py310h06a4308_0
#     cryptography:            2.2.2-py36h14c3975_0    --> 41.0.3-py310h130f0dd_0
#     idna:                    2.6-py36h82fb2a8_1      --> 3.7-py310h06a4308_0
#     libffi:                  3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:               7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:            7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     ncurses:                 6.1-hf484d3e_0          --> 6.3-h7f8727e_2
#     openssl:                 1.0.2o-h20670df_0       --> 1.1.1w-h7f8727e_0
#     pip:                     10.0.1-py36_0           --> 25.2-pyhc872135_1
#     pycosat:                 0.6.3-py36h0a5515d_0    --> 0.6.3-py310h7f8727e_0
#     pycparser:               2.18-py36hf9f622e_1     --> 2.23-py310h06a4308_0
#     pyopenssl:               18.0.0-py36_0           --> 23.2.0-py310h06a4308_0
#     python:                  3.6.5-hc3d631a_2        --> 3.10.4-h12debd9_0
#     readline:                7.0-ha6073c6_4          --> 8.1.2-h7f8727e_1
#     requests:                2.18.4-py36he2e5f8d_1   --> 2.32.5-py310h06a4308_0
#     setuptools:              39.2.0-py36_0           --> 80.9.0-py310h06a4308_0
#     sqlite:                  3.23.1-he433501_0       --> 3.38.5-hc218d9a_0
#     tk:                      8.6.7-hc745277_3        --> 8.6.12-h1ccaba5_0
#     urllib3:                 1.22-py36hbe7ace6_0     --> 2.1.0-py310h06a4308_0
#     wheel:                   0.31.1-py36_0           --> 0.45.1-py310h06a4308_0
#     xz:                      5.2.4-h14c3975_4        --> 5.2.5-h7f8727e_1
#     zlib:                    1.2.11-ha838bed_2       --> 1.2.12-h7f8727e_2
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# xz-5.2.5             |  389 KB | : 100% 1.0/1 [00:00<00:00,  4.70it/s]
# readline-8.1.2       |  423 KB | : 100% 1.0/1 [00:00<00:00,  7.79it/s]
# cffi-1.15.0          |  407 KB | : 100% 1.0/1 [00:00<00:00,  8.33it/s]
# libffi-3.3           |   54 KB | : 100% 1.0/1 [00:00<00:00, 19.37it/s]
# packaging-25.0       |  161 KB | : 100% 1.0/1 [00:00<00:00,  2.65it/s]
# boltons-25.0.0       |  422 KB | : 100% 1.0/1 [00:00<00:00,  6.07it/s]
# truststore-0.10.1    |   41 KB | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
# pyopenssl-23.2.0     |   93 KB | : 100% 1.0/1 [00:00<00:00,  3.16it/s]
# pip-25.2             |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# conda-package-handli |  275 KB | : 100% 1.0/1 [00:00<00:00, 10.21it/s]
# ld_impl_linux-64-2.4 |  706 KB | : 100% 1.0/1 [00:00<00:00,  6.56it/s]
# conda-package-stream |   33 KB | : 100% 1.0/1 [00:00<00:00, 16.91it/s]
# conda-23.9.0         |  994 KB | : 100% 1.0/1 [00:02<00:00,  2.22s/it]
# requests-2.32.5      |  143 KB | : 100% 1.0/1 [00:00<00:00, 10.01it/s]
# openssl-1.1.1w       |  3.8 MB | : 100% 1.0/1 [00:06<00:00,  6.56s/it]
# urllib3-2.1.0        |  143 KB | : 100% 1.0/1 [00:00<00:00, 10.39it/s]
# tqdm-4.67.1          |  125 KB | : 100% 1.0/1 [00:00<00:00, 10.82it/s]
# ca-certificates-2025 |  133 KB | : 100% 1.0/1 [00:00<00:00,  3.22it/s]
# tzdata-2025b         |  123 KB | : 100% 1.0/1 [00:00<00:00,  3.92it/s]
# libstdcxx-ng-9.1.0   |  4.0 MB | : 100% 1.0/1 [00:02<00:00,  2.33s/it]
# bzip2-1.0.8          |  105 KB | : 100% 1.0/1 [00:00<00:00, 14.31it/s]
# charset-normalizer-3 |   42 KB | : 100% 1.0/1 [00:00<00:00, 16.53it/s]
# certifi-2025.10.5    |  159 KB | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
# _libgcc_mutex-0.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 19.80it/s]
# python-3.10.4        | 24.2 MB | : 100% 1.0/1 [00:03<00:00,  3.84s/it]
# zstandard-0.15.2     |  2.5 MB | : 100% 1.0/1 [00:00<00:00,  2.39it/s]
# ruamel.yaml-0.16.10  |  170 KB | : 100% 1.0/1 [00:00<00:00,  1.39it/s]
# ruamel.yaml.clib-0.2 |  547 KB | : 100% 1.0/1 [00:00<00:00,  7.63it/s]
# pluggy-1.5.0         |   37 KB | : 100% 1.0/1 [00:00<00:00, 16.43it/s]
# wheel-0.45.1         |  108 KB | : 100% 1.0/1 [00:00<00:00, 11.41it/s]
# pycosat-0.6.3        |  206 KB | : 100% 1.0/1 [00:00<00:00, 13.73it/s]
# sqlite-3.38.5        |  1.5 MB | : 100% 1.0/1 [00:00<00:00,  3.84it/s]
# setuptools-80.9.0    |  1.8 MB | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
# tk-8.6.12            |  3.3 MB | : 100% 1.0/1 [00:00<00:00,  1.60it/s]
# zlib-1.2.12          |  130 KB | : 100% 1.0/1 [00:00<00:00, 13.53it/s]
# cryptography-41.0.3  |  2.1 MB | : 100% 1.0/1 [00:00<00:00,  1.99it/s]
# libuuid-1.0.3        |   18 KB | : 100% 1.0/1 [00:00<00:00,  3.06it/s]
# pycparser-2.23       |  239 KB | : 100% 1.0/1 [00:00<00:00,  2.50it/s]
# ncurses-6.3          |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
# jsonpointer-3.0.0    |   19 KB | : 100% 1.0/1 [00:00<00:00, 16.18it/s]
# jsonpatch-1.33       |   31 KB | : 100% 1.0/1 [00:00<00:00, 17.75it/s]
# idna-3.7             |  136 KB | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
# libgcc-ng-9.1.0      |  8.1 MB | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
# done
# done
# done

# %% [markdown]
# # New Section

# %%
# !conda env create -f STROBFL/environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.9.1
#
#
#
# Downloading and Extracting Packages:
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# joblib-1.2.0         | 205 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# xz-5.2.6             | 394 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# threadpoolctl-3.1.0  | 18 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# openssl-1.1.1q       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# tzdata-2022e         | 107 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 2 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# python_abi-3.9       | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ncurses-6.3          | 781 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 150 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 12 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.9.24    | 155 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# threadpoolctl-3.1.0  | 18 KB     | : 100% 1.0/1 [00:00<00:00, 10.98it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   2% 0.023396589615764136/1 [00:00<00:04,  4.35s/it]
#
#
#
#
# openssl-1.1.1q       | 2.5 MB    | :   1% 0.006184321777992511/1 [00:00<00:22, 23.07s/it]
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 1.781974218783329e-05/1 [00:00<2:58:30, 10710.84s/it]
# libgcc-ng-11.2.0     | 5.3 MB    | :  96% 0.9592601742463297/1 [00:00<00:00,  5.54it/s]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 2 KB      | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
#
#
#
#
#
#
#
# python_abi-3.9       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  4.18it/s]
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 2 KB      | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0.0027442402969263266/1 [00:00<01:25, 85.38s/it]
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | :  77% 0.768660567675346/1 [00:00<00:00,  2.65it/s]
#
# joblib-1.2.0         | 205 KB    | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
#
# joblib-1.2.0         | 205 KB    | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   0% 2.4615023747894033e-05/1 [00:00<3:36:07, 12967.41s/it]
#
#
# xz-5.2.6             | 394 KB    | :   4% 0.04056509876353697/1 [00:00<00:07,  8.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.006147811054802485/1 [00:00<00:49, 49.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | :   1% 0.013918149321082462/1 [00:00<00:27, 27.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | :   2% 0.024482928148642932/1 [00:00<00:15, 16.14s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.01017507278925281/1 [00:00<00:36, 36.75s/it]
#
#
#
#
#
#
#
#
# ncurses-6.3          | 781 KB    | :   2% 0.020475265094946793/1 [00:00<00:23, 24.29s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   1% 0.0071629719106371635/1 [00:00<00:52, 52.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 12 KB     | : 100% 1.0/1 [00:00<00:00,  1.83it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   1% 0.013240068445560135/1 [00:00<00:37, 38.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   1% 0.010387540021611281/1 [00:00<00:43, 43.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.9.24    | 155 KB    | :  10% 0.10323296095369512/1 [00:00<00:05,  6.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.01607340745342563/1 [00:00<00:39, 40.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.01872854903941279/1 [00:00<00:40, 40.98s/it]
#
#
#
#
# openssl-1.1.1q       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
#
#
#
#
# openssl-1.1.1q       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
#
#
#
#
#
#
#
# python_abi-3.9       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  4.18it/s]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   2% 0.019815094117054698/1 [00:00<00:34, 35.09s/it]
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.02127677217227295/1 [00:00<00:41, 42.21s/it]
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | : 100% 1.0/1 [00:00<00:00,  2.73it/s]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   2% 0.024341767828580274/1 [00:01<00:38, 39.05s/it]
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:01<00:00,  2.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 150 KB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 150 KB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   3% 0.0259934650777761/1 [00:01<00:33, 34.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   3% 0.0269790896723796/1 [00:01<00:39, 41.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
# tzdata-2022e         | 107 KB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
#
# tzdata-2022e         | 107 KB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   3% 0.030222282750565262/1 [00:01<00:36, 37.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :   1% 0.00599306064736687/1 [00:01<02:40, 161.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   3% 0.03369796751086693/1 [00:01<00:29, 30.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   3% 0.03294870330530376/1 [00:01<00:39, 41.17s/it]
#
#
# xz-5.2.6             | 394 KB    | : 100% 1.0/1 [00:01<00:00,  1.35s/it]
#
#
# xz-5.2.6             | 394 KB    | : 100% 1.0/1 [00:01<00:00,  1.35s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   4% 0.03707022576432841/1 [00:01<00:30, 31.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :   2% 0.02022657968486319/1 [00:01<00:40, 41.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.03546128695378825/1 [00:01<00:41, 43.17s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   4% 0.040270178851554636/1 [00:01<00:31, 32.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.9.24    | 155 KB    | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.03783131266477008/1 [00:01<00:42, 43.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :   4% 0.03595836388420122/1 [00:01<00:21, 22.70s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   4% 0.04337167184378928/1 [00:01<00:31, 32.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.040165698891376236/1 [00:01<00:43, 44.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   5% 0.046473164836023935/1 [00:01<00:31, 33.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.042428806149231064/1 [00:01<00:45, 48.01s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   5% 0.0495008127570149/1 [00:01<00:33, 35.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   4% 0.044549355469583225/1 [00:02<00:47, 49.50s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   5% 0.052380770535518505/1 [00:02<00:34, 36.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.046634265305559724/1 [00:02<00:46, 49.09s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   6% 0.05516226821903053/1 [00:02<00:34, 36.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.04870135539934838/1 [00:02<00:48, 50.80s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   6% 0.057943765902542556/1 [00:02<00:35, 37.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.05069716652438571/1 [00:02<00:48, 51.51s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   6% 0.060651418514810894/1 [00:02<00:36, 38.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.052657338165047377/1 [00:02<00:51, 54.09s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   6% 0.06326061103208766/1 [00:02<00:37, 39.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :  42% 0.4187651127347601/1 [00:02<00:01,  1.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   5% 0.05452841109476987/1 [00:02<00:53, 56.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   7% 0.06579595847812075/1 [00:02<00:38, 41.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.056506402477619365/1 [00:02<00:51, 54.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   7% 0.06842976601914541/1 [00:02<00:37, 40.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.05834183592296619/1 [00:02<00:52, 55.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | :  64% 0.6412574892682551/1 [00:02<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   7% 0.0709158834176827/1 [00:02<00:39, 42.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.06015944962612519/1 [00:02<00:54, 58.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   7% 0.07332815574497632/1 [00:02<00:38, 41.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.06204834229803552/1 [00:02<00:53, 56.67s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   8% 0.07574042807226994/1 [00:02<00:38, 42.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   6% 0.06383031651681885/1 [00:03<00:54, 57.96s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :   8% 0.07812808537581566/1 [00:03<00:39, 43.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   7% 0.066057784290298/1 [00:03<00:50, 53.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   7% 0.06898022200910267/1 [00:03<00:43, 46.21s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   7% 0.07268672838417199/1 [00:03<00:35, 38.30s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   8% 0.07646451372799265/1 [00:03<00:31, 33.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   8% 0.08065215314213348/1 [00:03<00:27, 30.15s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   8% 0.08400226467344614/1 [00:03<00:27, 30.11s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   9% 0.08735237620475879/1 [00:03<00:27, 30.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   9% 0.09068466799388361/1 [00:03<00:27, 30.30s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   9% 0.0939991400408206/1 [00:04<00:28, 31.21s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  10% 0.09738489105650894/1 [00:04<00:27, 30.75s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  10% 0.1007884618143851/1 [00:04<00:27, 30.38s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  10% 0.10410293386132209/1 [00:04<00:27, 30.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  11% 0.10736394668169558/1 [00:04<00:28, 32.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  11% 0.1104824015645664/1 [00:04<00:30, 33.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  11% 0.11356521696306156/1 [00:04<00:29, 33.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  12% 0.11659457313499322/1 [00:04<00:29, 33.72s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  12% 0.12060401512725571/1 [00:04<00:26, 30.63s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  13% 0.12564700216641253/1 [00:04<00:23, 26.44s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  13% 0.13124240121339217/1 [00:05<00:20, 23.20s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  14% 0.13641012644786385/1 [00:05<00:18, 21.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  14% 0.1418986070417165/1 [00:05<00:17, 20.69s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  15% 0.14760092454182314/1 [00:05<00:16, 19.66s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :  19% 0.19246487068478343/1 [00:05<00:13, 16.99s/it]
#
#
#
#
#
#
#
#
# ncurses-6.3          | 781 KB    | : 100% 1.0/1 [00:05<00:00,  5.31s/it]
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  15% 0.15380219482318913/1 [00:05<00:15, 18.46s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  16% 0.1592372161904783/1 [00:05<00:16, 19.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  17% 0.16554540492497127/1 [00:05<00:15, 18.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  17% 0.17210307005009393/1 [00:05<00:14, 17.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  18% 0.17821524162052074/1 [00:05<00:13, 16.99s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  18% 0.18441651190188674/1 [00:05<00:13, 16.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  19% 0.19140185083951738/1 [00:06<00:12, 15.94s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  20% 0.19769221983182253/1 [00:06<00:13, 17.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  21% 0.20531906948821518/1 [00:06<00:12, 15.80s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  21% 0.21273208223835383/1 [00:06<00:11, 15.07s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  22% 0.21945012504316697/1 [00:06<00:11, 15.08s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  23% 0.2261503481057923/1 [00:06<00:11, 15.28s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  23% 0.23383065698874844/1 [00:06<00:11, 14.55s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  24% 0.2414218671607654/1 [00:06<00:10, 14.14s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  25% 0.2485319442937109/1 [00:06<00:11, 14.98s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  26% 0.2552678068407119/1 [00:07<00:11, 14.99s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  26% 0.2634114290205517/1 [00:07<00:10, 14.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  27% 0.27246385805197104/1 [00:07<00:09, 13.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  28% 0.28017980641930285/1 [00:07<00:09, 13.39s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  29% 0.2876997376225685/1 [00:07<00:10, 14.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  30% 0.29545132547427594/1 [00:07<00:10, 14.34s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  30% 0.30257922234940926/1 [00:07<00:10, 14.68s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  31% 0.30951110206047644/1 [00:07<00:11, 17.02s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  32% 0.31565891311527894/1 [00:07<00:12, 18.42s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  32% 0.32130777138882205/1 [00:08<00:14, 20.89s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  33% 0.32633293868579105/1 [00:08<00:14, 21.20s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  33% 0.3312155480452574/1 [00:08<00:14, 21.51s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  34% 0.3359734192094089/1 [00:08<00:14, 21.73s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  34% 0.34064219166262116/1 [00:08<00:14, 21.97s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  35% 0.3479661057018207/1 [00:08<00:12, 18.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  35% 0.3537753416550543/1 [00:08<00:11, 18.38s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  36% 0.35945983941297316/1 [00:08<00:11, 18.16s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  37% 0.36503741871776496/1 [00:08<00:11, 18.42s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  37% 0.37086447441318643/1 [00:09<00:11, 18.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  38% 0.3764420537179783/1 [00:09<00:12, 19.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  38% 0.3816988776633891/1 [00:09<00:12, 20.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  39% 0.3865814870228554/1 [00:09<00:12, 21.07s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  39% 0.3914640963823217/1 [00:09<00:12, 20.92s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  40% 0.3962932465152246/1 [00:09<00:13, 22.24s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  40% 0.40085510051530987/1 [00:09<00:14, 24.79s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  41% 0.40500710044507504/1 [00:09<00:15, 25.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  41% 0.409711512382663/1 [00:10<00:14, 24.53s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  41% 0.4141664479296214/1 [00:10<00:14, 23.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.13        | 20.9 MB   | : 100% 1.0/1 [00:10<00:00,  1.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  42% 0.4184253663125135/1 [00:10<00:14, 25.09s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  42% 0.4240207653594932/1 [00:10<00:13, 22.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  44% 0.4424463787817128/1 [00:10<00:08, 14.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  46% 0.4567021725319794/1 [00:10<00:05, 11.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  47% 0.4670198032587349/1 [00:10<00:05, 10.61s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  48% 0.4765890048136014/1 [00:10<00:06, 12.47s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  49% 0.4877085239388093/1 [00:11<00:05, 11.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  50% 0.4978657769858743/1 [00:11<00:05, 10.88s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  51% 0.509983201673601/1 [00:11<00:04,  9.99s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudnn-8.1.0.77       | 634.8 MB  | :  66% 0.6568026786650565/1 [00:11<00:02,  8.46s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  52% 0.5203008324003564/1 [00:11<00:05, 10.61s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  54% 0.5404727805569837/1 [00:11<00:05, 11.43s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  55% 0.5497925057212205/1 [00:11<00:05, 11.23s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  56% 0.5589162137213912/1 [00:11<00:04, 11.23s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  57% 0.5679864624949983/1 [00:11<00:05, 11.74s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  58% 0.5766468571982853/1 [00:12<00:05, 12.31s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  59% 0.5851825137062574/1 [00:12<00:05, 12.14s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  59% 0.5940032860892349/1 [00:12<00:04, 11.91s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  60% 0.6034833889331622/1 [00:12<00:04, 11.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  61% 0.6137119209489785/1 [00:12<00:04, 10.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  63% 0.6251700151757553/1 [00:12<00:03, 10.18s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  64% 0.6371448819259793/1 [00:12<00:03,  9.57s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  65% 0.6507769846996718/1 [00:12<00:03,  8.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  66% 0.6639101346921049/1 [00:12<00:02,  8.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  68% 0.6790212760673876/1 [00:12<00:02,  7.78s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  69% 0.6922791642551355/1 [00:13<00:02,  7.71s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  71% 0.7053232155366295/1 [00:13<00:02,  7.70s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  72% 0.7183316273337478/1 [00:13<00:02,  7.69s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  73% 0.7335496871621574/1 [00:13<00:01,  7.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  75% 0.7479302191077389/1 [00:13<00:01,  7.21s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  76% 0.761811798272061/1 [00:13<00:01,  7.75s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  77% 0.7748736692957429/1 [00:13<00:01,  8.41s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  79% 0.787258390116287/1 [00:13<00:01,  8.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | : 100% 0.9986361719483654/1 [00:14<00:00,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | : 100% 1.0/1 [01:58<00:00,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# \ By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -
#   https://docs.nvidia.com/deeplearning/cudnn/sla/index.html
#
# done
# | Ran pip subprocess with arguments:
# ['/usr/local/envs/tf/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/STROBFL/condaenv.po48wglr.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting absl-py==1.3.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 1))
#   Downloading absl_py-1.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse==1.6.3 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 2))
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools==5.2.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 3))
#   Downloading cachetools-5.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting charset-normalizer==2.1.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 4))
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting flatbuffers==22.9.24 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 5))
#   Downloading flatbuffers-22.9.24-py2.py3-none-any.whl.metadata (874 bytes)
# Collecting gast==0.4.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 6))
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-auth==2.13.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 7))
#   Downloading google_auth-2.13.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting google-auth-oauthlib==0.4.6 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 8))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-pasta==0.2.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 9))
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting grpcio==1.50.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 10))
#   Downloading grpcio-1.50.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting h5py==3.7.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 11))
#   Downloading h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (1.8 kB)
# Collecting idna==3.4 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 12))
#   Downloading idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# Collecting importlib-metadata==5.0.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 13))
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting keras==2.10.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 14))
#   Downloading keras-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras-preprocessing==1.1.2 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 15))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang==14.0.6 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 16))
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.0 kB)
# Collecting markdown==3.4.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 17))
#   Downloading Markdown-3.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting markupsafe==2.1.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 18))
#   Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting numpy==1.23.4 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 19))
#   Downloading numpy-1.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting oauthlib==3.2.2 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 20))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting opt-einsum==3.3.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 21))
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pandas (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 22))
#   Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting packaging==21.3 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 23))
#   Downloading packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Collecting pip==22.3 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 24))
#   Downloading pip-22.3-py3-none-any.whl.metadata (4.1 kB)
# Collecting protobuf==3.19.6 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 25))
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (787 bytes)
# Collecting pyasn1==0.4.8 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 26))
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pyasn1-modules==0.2.8 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 27))
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pyparsing==3.0.9 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 28))
#   Downloading pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests==2.28.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 29))
#   Downloading requests-2.28.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-oauthlib==1.3.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 30))
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting rsa==4.9 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 31))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting six==1.16.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 32))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboard==2.10.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 33))
#   Downloading tensorboard-2.10.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorboard-data-server==0.6.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 34))
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit==1.8.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 35))
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting tensorflow==2.10.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 36))
#   Downloading tensorflow-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting tensorflow-estimator==2.10.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 37))
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem==0.27.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 38))
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting termcolor==2.0.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 39))
#   Downloading termcolor-2.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting typing-extensions==4.4.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 40))
#   Downloading typing_extensions-4.4.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting urllib3==1.26.12 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 41))
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl.metadata (47 kB)
# Collecting werkzeug==2.2.2 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 42))
#   Downloading Werkzeug-2.2.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting wrapt==1.14.1 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 43))
#   Downloading wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting zipp==3.9.0 (from -r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 44))
#   Downloading zipp-3.9.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/envs/tf/lib/python3.9/site-packages (from astunparse==1.6.3->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/tf/lib/python3.9/site-packages (from requests==2.28.1->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 29)) (2022.9.24)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/tf/lib/python3.9/site-packages (from tensorboard==2.10.1->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 33)) (63.4.1)
# Collecting python-dateutil>=2.8.2 (from pandas->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 22))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 22))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r /content/STROBFL/condaenv.po48wglr.requirements.txt (line 22))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Downloading flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Downloading google_auth-2.13.0-py2.py3-none-any.whl (174 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.50.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 6.4 MB/s  0:00:00
# Downloading h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 18.0 MB/s  0:00:00
# Downloading idna-3.4-py3-none-any.whl (61 kB)
# Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.2 MB/s  0:00:00
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 25.5 MB/s  0:00:00
# Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading numpy-1.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 65.2 MB/s  0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Downloading pip-22.3-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.3 MB/s  0:00:00
# Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.0 MB/s  0:00:00
# Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 22.0 MB/s  0:00:00
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 89.8 MB/s  0:00:00
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 36.6 MB/s  0:00:00
# Downloading tensorflow-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 21.2 MB/s  0:00:22
# Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Downloading tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 6.7 MB/s  0:00:00
# Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Downloading wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Downloading zipp-3.9.0-py3-none-any.whl (5.8 kB)
# Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 113.7 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tensorboard-plugin-wit, pytz, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, urllib3, tzdata, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, rsa, pyparsing, pyasn1-modules, protobuf, pip, oauthlib, numpy, markupsafe, idna, gast, charset-normalizer, cachetools, absl-py, werkzeug, requests, python-dateutil, packaging, opt-einsum, keras-preprocessing, importlib-metadata, h5py, grpcio, google-pasta, google-auth, astunparse, requests-oauthlib, pandas, markdown, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
#
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 charset-normalizer-2.1.1 flatbuffers-22.9.24 gast-0.4.0 google-auth-2.13.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 h5py-3.7.0 idna-3.4 importlib-metadata-5.0.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 markupsafe-2.1.1 numpy-1.23.4 oauthlib-3.2.2 opt-einsum-3.3.0 packaging-21.3 pandas-2.3.3 pip-22.3 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 six-1.16.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.1 typing-extensions-4.4.0 tzdata-2025.2 urllib3-1.26.12 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.9.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate tf
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda activate tf
# Out:
# usage: conda
#        [-h]
#        [-v]
#        [--no-plugins]
#        [-V]
#        COMMAND
#        ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'doctor', 'env')

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# tf                       /usr/local/envs/tf

# %%
# !cp -r /content/STROBFL/ /content/drive/MyDrive/STROBFL

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 131.3 MB/s  0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 174.1 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pandas]
# Successfully installed numpy-2.2.6 pandas-2.3.3 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
import os
import shutil
cdir = os.getcwd()
cdir = cdir+"/STROBFL"
shutil.rmtree(cdir)
