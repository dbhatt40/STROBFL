# %% [markdown]
# <a href="https://colab.research.google.com/github/dbhatt40/STROBFL/blob/main/STROBFL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dbhatt40/STROBFL.git
# Out:
# Cloning into 'STROBFL'...
# remote: Enumerating objects: 556, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 556 (delta 103), reused 171 (delta 46), pack-reused 321 (from 1)
# Receiving objects: 100% (556/556), 44.66 MiB | 21.14 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
# !bash ./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-12-26 05:51:56--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   300MB/s    in 0.2s
#
# 2025-12-26 05:51:56 (300 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !conda upgrade -n base conda
# Out:
# / y
# - y
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     libuuid-1.0.3              |       h7f8727e_2          18 KB
#     packaging-25.0             |  py310h06a4308_1         161 KB
#     certifi-2025.11.12         |  py310h06a4308_0         156 KB
#     urllib3-2.1.0              |  py310h06a4308_0         143 KB
#     pycparser-2.23             |  py310h06a4308_0         239 KB
#     tzdata-2025b               |       h04d1e81_0         123 KB
#     conda-package-handling-2.4.0|  py310h06a4308_1         275 KB
#     ruamel.yaml-0.16.10        |  py310h7f8727e_1         170 KB
#     setuptools-80.9.0          |  py310h06a4308_0         1.8 MB
#     wheel-0.45.1               |  py310h06a4308_0         108 KB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     tqdm-4.67.1                |  py310h7040dfc_1         125 KB
#     charset-normalizer-3.4.4   |  py310h06a4308_0          82 KB
#     conda-23.9.0               |  py310h06a4308_0         994 KB
#     xz-5.2.5                   |       h7f8727e_1         389 KB
#     truststore-0.10.1          |  py310h06a4308_1          38 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.8 MB
#     ruamel.yaml.clib-0.2.6     |  py310h7f8727e_0         547 KB
#     conda-package-streaming-0.12.0|  py310h06a4308_1          30 KB
#     sqlite-3.38.5              |       hc218d9a_0         1.5 MB
#     pluggy-1.5.0               |  py310h06a4308_0          37 KB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
#     jsonpatch-1.33             |  py310h06a4308_1          31 KB
#     idna-3.11                  |  py310h06a4308_0         235 KB
#     zlib-1.2.12                |       h7f8727e_2         130 KB
#     pyopenssl-23.2.0           |  py310h06a4308_0          93 KB
#     jsonpointer-3.0.0          |  py310h06a4308_0          19 KB
#     zstandard-0.15.2           |  py310h7f8727e_0         2.5 MB
#     pycosat-0.6.3              |  py310h7f8727e_0         206 KB
#     requests-2.32.5            |  py310h06a4308_1         141 KB
#     tk-8.6.12                  |       h1ccaba5_0         3.3 MB
#     cffi-1.15.0                |  py310hd667e15_1         407 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     ca-certificates-2025.12.2  |       h06a4308_0         132 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     boltons-25.0.0             |  py310h06a4308_0         422 KB
#     pip-25.3                   |     pyhc872135_0         1.4 MB
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         706 KB
#     cryptography-41.0.3        |  py310h130f0dd_0         2.1 MB
#     python-3.10.4              |       h12debd9_0        24.2 MB
#     ------------------------------------------------------------
#                                            Total:        60.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:           0.1-main
#     boltons:                 25.0.0-py310h06a4308_0
#     bzip2:                   1.0.8-h7b6447c_0
#     charset-normalizer:      3.4.4-py310h06a4308_0
#     conda-package-handling:  2.4.0-py310h06a4308_1
#     conda-package-streaming: 0.12.0-py310h06a4308_1
#     jsonpatch:               1.33-py310h06a4308_1
#     jsonpointer:             3.0.0-py310h06a4308_0
#     ld_impl_linux-64:        2.40-h12ee557_0
#     libuuid:                 1.0.3-h7f8727e_2
#     packaging:               25.0-py310h06a4308_1
#     pluggy:                  1.5.0-py310h06a4308_0
#     ruamel.yaml:             0.16.10-py310h7f8727e_1
#     ruamel.yaml.clib:        0.2.6-py310h7f8727e_0
#     tqdm:                    4.67.1-py310h7040dfc_1
#     truststore:              0.10.1-py310h06a4308_1
#     tzdata:                  2025b-h04d1e81_0
#     zstandard:               0.15.2-py310h7f8727e_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:         2018.03.07-0            --> 2025.12.2-h06a4308_0
#     certifi:                 2018.4.16-py36_0        --> 2025.11.12-py310h06a4308_0
#     cffi:                    1.11.5-py36h9745a5d_0   --> 1.15.0-py310hd667e15_1
#     conda:                   4.5.4-py36_0            --> 23.9.0-py310h06a4308_0
#     cryptography:            2.2.2-py36h14c3975_0    --> 41.0.3-py310h130f0dd_0
#     idna:                    2.6-py36h82fb2a8_1      --> 3.11-py310h06a4308_0
#     libffi:                  3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:               7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:            7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     ncurses:                 6.1-hf484d3e_0          --> 6.3-h7f8727e_2
#     openssl:                 1.0.2o-h20670df_0       --> 1.1.1w-h7f8727e_0
#     pip:                     10.0.1-py36_0           --> 25.3-pyhc872135_0
#     pycosat:                 0.6.3-py36h0a5515d_0    --> 0.6.3-py310h7f8727e_0
#     pycparser:               2.18-py36hf9f622e_1     --> 2.23-py310h06a4308_0
#     pyopenssl:               18.0.0-py36_0           --> 23.2.0-py310h06a4308_0
#     python:                  3.6.5-hc3d631a_2        --> 3.10.4-h12debd9_0
#     readline:                7.0-ha6073c6_4          --> 8.1.2-h7f8727e_1
#     requests:                2.18.4-py36he2e5f8d_1   --> 2.32.5-py310h06a4308_1
#     setuptools:              39.2.0-py36_0           --> 80.9.0-py310h06a4308_0
#     sqlite:                  3.23.1-he433501_0       --> 3.38.5-hc218d9a_0
#     tk:                      8.6.7-hc745277_3        --> 8.6.12-h1ccaba5_0
#     urllib3:                 1.22-py36hbe7ace6_0     --> 2.1.0-py310h06a4308_0
#     wheel:                   0.31.1-py36_0           --> 0.45.1-py310h06a4308_0
#     xz:                      5.2.4-h14c3975_4        --> 5.2.5-h7f8727e_1
#     zlib:                    1.2.11-ha838bed_2       --> 1.2.12-h7f8727e_2
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# libstdcxx-ng-9.1.0   |  4.0 MB | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
# libuuid-1.0.3        |   18 KB | : 100% 1.0/1 [00:00<00:00, 18.21it/s]
# packaging-25.0       |  161 KB | : 100% 1.0/1 [00:00<00:00,  6.27it/s]
# certifi-2025.11.12   |  156 KB | : 100% 1.0/1 [00:00<00:00, 12.34it/s]
# urllib3-2.1.0        |  143 KB | : 100% 1.0/1 [00:00<00:00,  9.01it/s]
# pycparser-2.23       |  239 KB | : 100% 1.0/1 [00:00<00:00,  6.41it/s]
# tzdata-2025b         |  123 KB | : 100% 1.0/1 [00:00<00:00,  3.96it/s]
# conda-package-handli |  275 KB | : 100% 1.0/1 [00:00<00:00, 10.46it/s]
# ruamel.yaml-0.16.10  |  170 KB | : 100% 1.0/1 [00:00<00:00,  9.84it/s]
# setuptools-80.9.0    |  1.8 MB | : 100% 1.0/1 [00:00<00:00,  1.51it/s]
# wheel-0.45.1         |  108 KB | : 100% 1.0/1 [00:00<00:00, 11.23it/s]
# readline-8.1.2       |  423 KB | : 100% 1.0/1 [00:00<00:00,  7.58it/s]
# tqdm-4.67.1          |  125 KB | : 100% 1.0/1 [00:00<00:00,  9.24it/s]
# charset-normalizer-3 |   82 KB | : 100% 1.0/1 [00:00<00:00, 10.00it/s]
# conda-23.9.0         |  994 KB | : 100% 1.0/1 [00:00<00:00,  2.14it/s]
# xz-5.2.5             |  389 KB | : 100% 1.0/1 [00:00<00:00,  6.87it/s]
# truststore-0.10.1    |   38 KB | : 100% 1.0/1 [00:00<00:00, 14.84it/s]
# openssl-1.1.1w       |  3.8 MB | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
# ruamel.yaml.clib-0.2 |  547 KB | : 100% 1.0/1 [00:00<00:00,  7.05it/s]
# conda-package-stream |   30 KB | : 100% 1.0/1 [00:00<00:00, 17.59it/s]
# sqlite-3.38.5        |  1.5 MB | : 100% 1.0/1 [00:00<00:00,  3.34it/s]
# pluggy-1.5.0         |   37 KB | : 100% 1.0/1 [00:00<00:00, 14.08it/s]
# ncurses-6.3          |  1.0 MB | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
# jsonpatch-1.33       |   31 KB | : 100% 1.0/1 [00:00<00:00, 16.76it/s]
# idna-3.11            |  235 KB | : 100% 1.0/1 [00:00<00:00,  8.05it/s]
# zlib-1.2.12          |  130 KB | : 100% 1.0/1 [00:00<00:00, 12.11it/s]
# pyopenssl-23.2.0     |   93 KB | : 100% 1.0/1 [00:00<00:00, 10.41it/s]
# jsonpointer-3.0.0    |   19 KB | : 100% 1.0/1 [00:00<00:00, 15.68it/s]
# zstandard-0.15.2     |  2.5 MB | : 100% 1.0/1 [00:00<00:00,  2.37it/s]
# pycosat-0.6.3        |  206 KB | : 100% 1.0/1 [00:00<00:00, 12.39it/s]
# requests-2.32.5      |  141 KB | : 100% 1.0/1 [00:00<00:00,  2.51it/s]
# tk-8.6.12            |  3.3 MB | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
# cffi-1.15.0          |  407 KB | : 100% 1.0/1 [00:00<00:00,  8.25it/s]
# libffi-3.3           |   54 KB | : 100% 1.0/1 [00:00<00:00, 15.43it/s]
# ca-certificates-2025 |  132 KB | : 100% 1.0/1 [00:00<00:00, 15.32it/s]
# libgcc-ng-9.1.0      |  8.1 MB | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
# boltons-25.0.0       |  422 KB | : 100% 1.0/1 [00:00<00:00,  5.90it/s]
# pip-25.3             |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  1.94it/s]
# bzip2-1.0.8          |  105 KB | : 100% 1.0/1 [00:00<00:00, 11.78it/s]
# _libgcc_mutex-0.1    |    3 KB | : 100% 1.0/1 [00:00<00:00, 22.28it/s]
# ld_impl_linux-64-2.4 |  706 KB | : 100% 1.0/1 [00:00<00:00,  5.98it/s]
# cryptography-41.0.3  |  2.1 MB | : 100% 1.0/1 [00:00<00:00,  1.98it/s]
# python-3.10.4        | 24.2 MB | : 100% 1.0/1 [00:04<00:00,  4.01s/it]
# done
# done
# done

# %% [markdown]
# # New Section

# %%
# !conda env create -f STROBFL/environment.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.11.1
#
#
#
# Downloading and Extracting Packages:
# libgfortran5-12.2.0  | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
# openssl-1.1.1q       | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# setuptools-63.4.1    | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# joblib-1.2.0         | 205 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# wheel-0.37.1         | 33 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libopenblas-0.3.20   | 10.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# liblapack-3.9.0      | 12 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# sqlite-3.39.3        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# scipy-1.8.1          | 24.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 12 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-11.2.0       | 474 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2022e         | 107 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 150 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-5.2.6             | 394 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-12.2.0  | 1.8 MB    | :   1% 0.008905499733117652/1 [00:00<00:12, 12.19s/it]
#
#
#
# wheel-0.37.1         | 33 KB     | :  49% 0.491583905907768/1 [00:00<00:00,  4.53it/s]
# openssl-1.1.1q       | 2.5 MB    | :   1% 0.006184321777992511/1 [00:00<00:20, 21.02s/it]
#
#
#
# wheel-0.37.1         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  4.53it/s]
#
# setuptools-63.4.1    | 1.1 MB    | :   1% 0.014770127273350125/1 [00:00<00:09,  9.18s/it]
#
#
# joblib-1.2.0         | 205 KB    | :   8% 0.07801087505118512/1 [00:00<00:02,  2.49s/it]
#
#
#
#
# libopenblas-0.3.20   | 10.1 MB   | :   0% 0.0015493585207484392/1 [00:00<02:09, 129.73s/it]
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0.002924573701970517/1 [00:00<01:24, 84.42s/it]
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | :  77% 0.768660567675346/1 [00:00<00:00,  2.64it/s]
#
#
#
#
# libopenblas-0.3.20   | 10.1 MB   | :  24% 0.2447986462782534/1 [00:00<00:00,  1.01it/s]
#
#
#
#
#
#
#
# liblapack-3.9.0      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  3.05it/s]
#
#
#
#
#
#
# libgcc-ng-11.2.0     | 5.3 MB    | :  57% 0.5732164455862214/1 [00:00<00:00,  2.09it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.3 | 654 KB    | :   2% 0.024482928148642932/1 [00:00<00:13, 14.21s/it]
#
#
#
#
#
#
#
#
#
# sqlite-3.39.3        | 1.1 MB    | :   1% 0.014763991504216803/1 [00:00<00:23, 24.07s/it]
#
#
#
#
#
#
#
#
#
#
# scipy-1.8.1          | 24.9 MB   | :   0% 
99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  61% 0.6148167449646242/1 [00:13<00:05, 15.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  63% 0.6269876288789143/1 [00:13<00:04, 12.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  64% 0.6394970878947733/1 [00:13<00:03, 10.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  65% 0.6539845382934818/1 [00:13<00:03,  9.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  67% 0.6686680058562564/1 [00:13<00:02,  8.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  68% 0.680785430543983/1 [00:14<00:03, 11.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  69% 0.6938829410520405/1 [00:14<00:03, 10.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  71% 0.7105443999976646/1 [00:14<00:02,  8.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  72% 0.723125137982275/1 [00:14<00:02,  8.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  74% 0.7372740132794146/1 [00:14<00:02,  8.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  75% 0.7528841074359566/1 [00:14<00:01,  7.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  77% 0.7700801586472157/1 [00:14<00:01,  6.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  79% 0.7868485360459668/1 [00:14<00:01,  6.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  80% 0.8034565357650274/1 [00:14<00:01,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  82% 0.820492209296596/1 [00:14<00:01,  6.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  84% 0.8373675051484741/1 [00:15<00:01,  6.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  85% 0.8537794877034687/1 [00:15<00:00,  6.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  87% 0.8711359165944182/1 [00:15<00:00,  6.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  89% 0.8877973755400423/1 [00:15<00:00,  6.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  91% 0.9068288601966483/1 [00:15<00:00,  6.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  93% 0.9278026967517281/1 [00:15<00:00,  5.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  95% 0.9455689797129979/1 [00:15<00:00,  5.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  96% 0.9631214257680137/1 [00:15<00:00,  6.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | :  98% 0.9793552109011299/1 [00:15<00:00,  7.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | : 100% 0.997620446643659/1 [00:16<00:00,  6.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.2.2   | 876.8 MB  | : 100% 1.0/1 [02:03<00:00,  6.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# | By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -
#   https://docs.nvidia.com/deeplearning/cudnn/sla/index.html
#
# done
# / Ran pip subprocess with arguments:
# ['/usr/local/envs/tf/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/STROBFL/condaenv.vgjpewcv.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting absl-py==1.3.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 1))
#   Downloading absl_py-1.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse==1.6.3 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 2))
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools==5.2.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 3))
#   Downloading cachetools-5.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting charset-normalizer==2.1.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 4))
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting flatbuffers==22.9.24 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 5))
#   Downloading flatbuffers-22.9.24-py2.py3-none-any.whl.metadata (874 bytes)
# Collecting gast==0.4.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 6))
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-auth==2.13.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 7))
#   Downloading google_auth-2.13.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting google-auth-oauthlib==0.4.6 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 8))
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-pasta==0.2.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 9))
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting grpcio==1.50.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 10))
#   Downloading grpcio-1.50.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting h5py==3.7.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 11))
#   Downloading h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (1.8 kB)
# Collecting idna==3.4 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 12))
#   Downloading idna-3.4-py3-none-any.whl.metadata (9.8 kB)
# Collecting importlib-metadata==5.0.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 13))
#   Downloading importlib_metadata-5.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting keras==2.10.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 14))
#   Downloading keras-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras-preprocessing==1.1.2 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 15))
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting libclang==14.0.6 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 16))
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.0 kB)
# Collecting markdown==3.4.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 17))
#   Downloading Markdown-3.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting markupsafe==2.1.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 18))
#   Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting matplotlib (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy==1.23.4 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 20))
#   Downloading numpy-1.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting oauthlib==3.2.2 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 21))
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting opt-einsum==3.3.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 22))
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pandas (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 23))
#   Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting packaging==21.3 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 24))
#   Downloading packaging-21.3-py3-none-any.whl.metadata (15 kB)
# Collecting pip==22.3 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 25))
#   Downloading pip-22.3-py3-none-any.whl.metadata (4.1 kB)
# Collecting protobuf==3.19.6 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 26))
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (787 bytes)
# Collecting pyasn1==0.4.8 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 27))
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting pyasn1-modules==0.2.8 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 28))
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pyparsing==3.0.9 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 29))
#   Downloading pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests==2.28.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 30))
#   Downloading requests-2.28.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-oauthlib==1.3.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 31))
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting rsa==4.9 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 32))
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting six==1.16.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 33))
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboard==2.10.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 34))
#   Downloading tensorboard-2.10.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorboard-data-server==0.6.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 35))
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit==1.8.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 36))
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting tensorflow==2.10.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 37))
#   Downloading tensorflow-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting tensorflow-estimator==2.10.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 38))
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting tensorflow-io-gcs-filesystem==0.27.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 39))
#   Downloading tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting termcolor==2.0.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 40))
#   Downloading termcolor-2.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting typing-extensions==4.4.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 41))
#   Downloading typing_extensions-4.4.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting urllib3==1.26.12 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 42))
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl.metadata (47 kB)
# Collecting werkzeug==2.2.2 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 43))
#   Downloading Werkzeug-2.2.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting wrapt==1.14.1 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 44))
#   Downloading wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting zipp==3.9.0 (from -r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 45))
#   Downloading zipp-3.9.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/envs/tf/lib/python3.9/site-packages (from astunparse==1.6.3->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/tf/lib/python3.9/site-packages (from requests==2.28.1->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 30)) (2022.9.24)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/envs/tf/lib/python3.9/site-packages (from tensorboard==2.10.1->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 34)) (63.4.1)
# Collecting contourpy>=1.0.1 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading fonttools-4.60.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (113 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 19))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytz>=2020.1 (from pandas->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 23))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r /content/STROBFL/condaenv.vgjpewcv.requirements.txt (line 23))
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Downloading flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Downloading google_auth-2.13.0-py2.py3-none-any.whl (174 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.50.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 58.4 MB/s  0:00:00
# Downloading h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 54.2 MB/s  0:00:00
# Downloading idna-3.4-py3-none-any.whl (61 kB)
# Downloading importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
# Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.2 MB/s  0:00:00
# Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 151.7 MB/s  0:00:00
# Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading numpy-1.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 84.1 MB/s  0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Downloading pip-22.3-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.8 MB/s  0:00:00
# Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.0 MB/s  0:00:00
# Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
# Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 110.9 MB/s  0:00:00
# Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 43.5 MB/s  0:00:00
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 32.2 MB/s  0:00:00
# Downloading tensorflow-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.1/578.1 MB 47.7 MB/s  0:00:08
# Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# Downloading tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.7 MB/s  0:00:00
# Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Downloading wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Downloading zipp-3.9.0-py3-none-any.whl (5.8 kB)
# Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 166.4 MB/s  0:00:00
# Downloading pandas-2.3.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 182.2 MB/s  0:00:00
# Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.2-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 152.2 MB/s  0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 76.1 MB/s  0:00:00
# Downloading pillow-11.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 148.6 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tensorboard-plugin-wit, pytz, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, urllib3, tzdata, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, rsa, pyparsing, pyasn1-modules, protobuf, pip, pillow, oauthlib, numpy, markupsafe, kiwisolver, idna, gast, fonttools, cycler, charset-normalizer, cachetools, absl-py, werkzeug, requests, python-dateutil, packaging, opt-einsum, keras-preprocessing, importlib-resources, importlib-metadata, h5py, grpcio, google-pasta, google-auth, contourpy, astunparse, requests-oauthlib, pandas, matplotlib, markdown, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
#
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 charset-normalizer-2.1.1 contourpy-1.3.0 cycler-0.12.1 flatbuffers-22.9.24 fonttools-4.60.2 gast-0.4.0 google-auth-2.13.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.50.0 h5py-3.7.0 idna-3.4 importlib-metadata-5.0.0 importlib-resources-6.5.2 keras-2.10.0 keras-preprocessing-1.1.2 kiwisolver-1.4.7 libclang-14.0.6 markdown-3.4.1 markupsafe-2.1.1 matplotlib-3.9.4 numpy-1.23.4 oauthlib-3.2.2 opt-einsum-3.3.0 packaging-21.3 pandas-2.3.3 pillow-11.3.0 pip-22.3 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 six-1.16.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.27.0 termcolor-2.0.1 typing-extensions-4.4.0 tzdata-2025.3 urllib3-1.26.12 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.9.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate tf
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda init bash
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.10/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda activate tf
# Out:
# usage: conda
#        [-h]
#        [-v]
#        [--no-plugins]
#        [-V]
#        COMMAND
#        ...
# conda: error: argument COMMAND: invalid choice: 'activate' (choose from 'clean', 'compare', 'config', 'create', 'info', 'init', 'install', 'list', 'notices', 'package', 'remove', 'uninstall', 'rename', 'run', 'search', 'update', 'upgrade', 'doctor', 'env')

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# tf                       /usr/local/envs/tf

# %%
# !cp -r /content/STROBFL/* /content/drive/MyDrive/STROBFL

# %%
import os
import shutil
cdir = os.getcwd()
cdir = cdir+"/STROBFL"
shutil.rmtree(cdir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4060173637.py in <cell line: 0>()
#       3 cdir = os.getcwd()
#       4 cdir = cdir+"/STROBFL"
# ----> 5 shutil.rmtree(cdir)
#       6
#
# /usr/lib/python3.12/shutil.py in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     757         try:
#     758             while stack:
# --> 759                 _rmtree_safe_fd(stack, onexc)
#     760         finally:
#     761             # Close any file descriptors still on the stack.
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     701     except OSError as err:
#     702         err.filename = path
# --> 703         onexc(func, path, err)
#     704
#     705 _use_fd_functions = ({os.open, os.stat, os.unlink, os.rmdir} <=
#
# /usr/lib/python3.12/shutil.py in _rmtree_safe_fd(stack, onexc)
#     667         assert func is os.lstat
#     668         if orig_entry is None:
# --> 669             orig_st = os.lstat(name, dir_fd=dirfd)
#     670         else:
#     671             orig_st = orig_entry.stat(follow_symlinks=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/STROBFL'

# %%
import os
import shutil
cdir = os.getcwd()
codir = os.path.join(cdir,"STROBFL/output_files")
os.system(f"rm -r {codir}/*")
cwdir = os.path.join(cdir,"STROBFL/weights")
os.system(f"rm -r {cwdir}/*")
# Out:
# 0

# %%
rm -rf /content/drive/MyDrive/STROBFL/*
